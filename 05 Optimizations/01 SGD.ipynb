# %%
# Stochastic Gradient Descent : Parameters are updated after computing the gradient of error with respect to a single training 
#                               example

# %%
import numpy as np
from numpy import random
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

x = [30, 35, 37, 59, 70, 76, 88, 100]
y = [1100, 1423, 1377, 1800, 2304, 2588, 3495, 4839]

x = np.reshape(x,(-1,1))
y = np.reshape(y,(-1,1))

scaler = MinMaxScaler()
scaler.fit(x)
x = scaler.transform(x)

#scaler.fit(y)
#y = scaler.transform(y

# %%
theta0 =0
theta1 =0

learningrate = 0.1

loss = []
iteration = []

# %%
print("In SGD Weights are updated for every samples in dataset also considered singled sample for finding \nprediction and cost value generation")


for steps in range(100):
    
    seed = np.random.random()
    np.random.seed(int(seed))
    np.random.shuffle(x)
    np.random.seed(int(seed))
    np.random.shuffle(y)
    
    print("Epoch:",steps)
    
    for i in range(0,1):
        
        print("Number of Samples:",len(x[i]))
        
        print("\ttheta0:{0} \n\ttheta1:{1}".format(theta0,theta1))

        predicted = theta0 + (x[i] * theta1)
        #print("predicted:=",predicted)

        cost = np.square(np.subtract(y[i],predicted)) / 2
        print("\tcost:=",cost)
        
        loss.append(cost)
        iteration.append(steps)

        dtheta0 = -1 * (y[i] - predicted)
        dtheta1 = (-x[i]) * (y[i] - predicted)

        theta0 = theta0 - learningrate * dtheta0
        theta1 = theta1 - learningrate * dtheta1
# Out:
# In SGD Weights are updated for every samples in dataset also considered singled sample for finding
# prediction and cost value generation
# Epoch: 0
# Number of Samples: 1
# 	theta0:0
# 	theta1:0
# 	cost:= [3348872.]
# Epoch: 1
# Number of Samples: 1
# 	theta0:[258.8]
# 	theta1:[170.06857143]
# 	cost:= [353808.72]
# Epoch: 2
# Number of Samples: 1
# 	theta0:[342.92]
# 	theta1:[170.06857143]
# 	cost:= [4533560.46268274]
# Epoch: 3
# Number of Samples: 1
# 	theta0:[644.03660408]
# 	theta1:[419.56518624]
# 	cost:= [1391527.58099987]
# Epoch: 4
# Number of Samples: 1
# 	theta0:[810.86151715]
# 	theta1:[529.19298625]
# 	cost:= [41800.53113263]
# Epoch: 5
# Number of Samples: 1
# 	theta0:[839.77536543]
# 	theta1:[529.19298625]
# 	cost:= [2456991.26981982]
# Epoch: 6
# Number of Samples: 1
# 	theta0:[1061.45041003]
# 	theta1:[712.86659463]
# 	cost:= [559781.87882064]
# Epoch: 7
# Number of Samples: 1
# 	theta0:[1167.25984995]
# 	theta1:[782.3985123]
# 	cost:= [2261.9437077]
# Epoch: 8
# Number of Samples: 1
# 	theta0:[1160.53386496]
# 	theta1:[782.3985123]
# 	cost:= [1421623.55489011]
# Epoch: 9
# Number of Samples: 1
# 	theta0:[1329.15317316]
# 	theta1:[922.11165338]
# 	cost:= [213131.20074313]
# Epoch: 10
# Number of Samples: 1
# 	theta0:[1394.44194719]
# 	theta1:[965.01570488]
# 	cost:= [43348.0301324]
# Epoch: 11
# Number of Samples: 1
# 	theta0:[1364.99775247]
# 	theta1:[965.01570488]
# 	cost:= [885005.76971257]
# Epoch: 12
# Number of Samples: 1
# 	theta0:[1498.0395331]
# 	theta1:[1075.25032312]
# 	cost:= [73485.28069999]
# Epoch: 13
# Number of Samples: 1
# 	theta0:[1536.37627285]
# 	theta1:[1100.44303781]
# 	cost:= [95212.12575147]
# Epoch: 14
# Number of Samples: 1
# 	theta0:[1492.73864556]
# 	theta1:[1100.44303781]
# 	cost:= [594557.7154821]
# Epoch: 15
# Number of Samples: 1
# 	theta0:[1601.78521502]
# 	theta1:[1190.79590964]
# 	cost:= [20745.16627039]
# Epoch: 16
# Number of Samples: 1
# 	theta0:[1622.15439088]
# 	theta1:[1204.18136807]
# 	cost:= [136322.60395758]
# Epoch: 17
# Number of Samples: 1
# 	theta0:[1569.93895179]
# 	theta1:[1204.18136807]
# 	cost:= [429952.63375514]
# Epoch: 18
# Number of Samples: 1
# 	theta0:[1662.67002897]
# 	theta1:[1281.01568916]
# 	cost:= [3487.76688731]
# Epoch: 19
# Number of Samples: 1
# 	theta0:[1671.02199507]
# 	theta1:[1286.50412403]
# 	cost:= [163033.05942875]
# Epoch: 20
# Number of Samples: 1
# 	theta0:[1613.91979557]
# 	theta1:[1286.50412403]
# 	cost:= [332210.0174451]
# Epoch: 21
# Number of Samples: 1
# 	theta0:[1695.43176002]
# 	theta1:[1354.04260886]
# 	cost:= [3.83315801]
# Epoch: 22
# Number of Samples: 1
# 	theta0:[1695.70864115]
# 	theta1:[1354.22455932]
# 	cost:= [177434.39256957]
# Epoch: 23
# Number of Samples: 1
# 	theta0:[1636.13777703]
# 	theta1:[1354.22455932]
# 	cost:= [271430.08010295]
# Epoch: 24
# Number of Samples: 1
# 	theta0:[1709.81682156]
# 	theta1:[1415.27291049]
# 	cost:= [1344.38265072]
# Epoch: 25
# Number of Samples: 1
# 	theta0:[1704.631491]
# 	theta1:[1411.86540756]
# 	cost:= [182789.61995358]
# Epoch: 26
# Number of Samples: 1
# 	theta0:[1644.1683419]
# 	theta1:[1411.86540756]
# 	cost:= [231880.71820082]
# Epoch: 27
# Number of Samples: 1
# 	theta0:[1712.26837394]
# 	theta1:[1468.29114839]
# 	cost:= [3973.45244629]
# Epoch: 28
# Number of Samples: 1
# 	theta0:[1703.35383251]
# 	theta1:[1462.43302116]
# 	cost:= [182017.9236016]
# Epoch: 29
# Number of Samples: 1
# 	theta0:[1643.01844926]
# 	theta1:[1462.43302116]
# 	cost:= [204960.88483624]
# Epoch: 30
# Number of Samples: 1
# 	theta0:[1707.04358258]
# 	theta1:[1515.48241734]
# 	cost:= [6604.68556017]
# Epoch: 31
# Number of Samples: 1
# 	theta0:[1695.55037975]
# 	theta1:[1507.9297412]
# 	cost:= [177340.12741167]
# Epoch: 32
# Number of Samples: 1
# 	theta0:[1635.99534178]
# 	theta1:[1507.9297412]
# 	cost:= [185792.15600365]
# Epoch: 33
# Number of Samples: 1
# 	theta0:[1696.95305761]
# 	theta1:[1558.43756289]
# 	cost:= [8853.70205194]
# Epoch: 34
# Number of Samples: 1
# 	theta0:[1683.64614058]
# 	theta1:[1549.69301741]
# 	cost:= [170321.40870519]
# Epoch: 35
# Number of Samples: 1
# 	theta0:[1625.28152652]
# 	theta1:[1549.69301741]
# 	cost:= [171514.69903897]
# Epoch: 36
# Number of Samples: 1
# 	theta0:[1683.85023814]
# 	theta1:[1598.22137847]
# 	cost:= [10674.0662155]
# Epoch: 37
# Number of Samples: 1
# 	theta0:[1669.23923803]
# 	theta1:[1588.61986411]
# 	cost:= [162016.65505398]
# Epoch: 38
# Number of Samples: 1
# 	theta0:[1612.31531422]
# 	theta1:[1588.61986411]
# 	cost:= [160404.284884]
# Epoch: 39
# Number of Samples: 1
# 	theta0:[1668.95527977]
# 	theta1:[1635.55012128]
# 	cost:= [12128.30849867]
# Epoch: 40
# Number of Samples: 1
# 	theta0:[1653.38074383]
# 	theta1:[1625.31542623]
# 	cost:= [153115.12381942]
# Epoch: 41
# Number of Samples: 1
# 	theta0:[1598.04266944]
# 	theta1:[1625.31542623]
# 	cost:= [151397.10903413]
# Epoch: 42
# Number of Samples: 1
# 	theta0:[1653.06941004]
# 	theta1:[1670.90901129]
# 	cost:= [13300.04361917]
# Epoch: 43
# Number of Samples: 1
# 	theta0:[1636.75987687]
# 	theta1:[1660.19131807]
# 	cost:= [144055.58270672]
# Epoch: 44
# Number of Samples: 1
# 	theta0:[1583.08388918]
# 	theta1:[1660.19131807]
# 	cost:= [143824.40815469]
# Epoch: 45
# Number of Samples: 1
# 	theta0:[1636.71679105]
# 	theta1:[1704.63000819]
# 	cost:= [14263.98080531]
# Epoch: 46
# Number of Samples: 1
# 	theta0:[1619.82656855]
# 	theta1:[1693.53071912]
# 	cost:= [135109.83068539]
# Epoch: 47
# Number of Samples: 1
# 	theta0:[1567.8439117]
# 	theta1:[1693.53071912]
# 	cost:= [137259.14014055]
# Epoch: 48
# Number of Samples: 1
# 	theta0:[1620.2384038]
# 	theta1:[1736.94329829]
# 	cost:= [15078.60006672]
# Epoch: 49
# Number of Samples: 1
# 	theta0:[1602.87257525]
# 	theta1:[1725.5314681]
# 	cost:= [126440.41346726]
# Epoch: 50
# Number of Samples: 1
# 	theta0:[1552.58531772]
# 	theta1:[1725.5314681]
# 	cost:= [131424.80475257]
# Epoch: 51
# Number of Samples: 1
# 	theta0:[1603.85417859]
# 	theta1:[1768.01138139]
# 	cost:= [15786.90878006]
# Epoch: 52
# Number of Samples: 1
# 	theta0:[1586.08515567]
# 	theta1:[1756.3345949]
# 	cost:= [118139.38928176]
# Epoch: 53
# Number of Samples: 1
# 	theta0:[1537.4766401]
# 	theta1:[1756.3345949]
# 	cost:= [126139.93489642]
# Epoch: 54
# Number of Samples: 1
# 	theta0:[1587.70410966]
# 	theta1:[1797.9516411]
# 	cost:= [16419.47219837]
# Epoch: 55
# Number of Samples: 1
# 	theta0:[1569.58259085]
# 	theta1:[1786.04321445]
# 	cost:= [110253.90481443]
# Epoch: 56
# Number of Samples: 1
# 	theta0:[1522.62433176]
# 	theta1:[1786.04321445]
# 	cost:= [121283.68565731]
# Epoch: 57
# Number of Samples: 1
# 	theta0:[1571.87546082]
# 	theta1:[1826.85129281]
# 	cost:= [16997.57531078]
# Epoch: 58
# Number of Samples: 1
# 	theta0:[1553.43768692]
# 	theta1:[1814.7350414]
# 	cost:= [102802.86796135]
# Epoch: 59
# Number of Samples: 1
# 	theta0:[1508.09391823]
# 	theta1:[1814.7350414]
# 	cost:= [116774.2099672]
# Epoch: 60
# Number of Samples: 1
# 	theta0:[1556.42076584]
# 	theta1:[1854.77728655]
# 	cost:= [17535.85256108]
# Epoch: 61
# Number of Samples: 1
# 	theta0:[1537.69332471]
# 	theta1:[1842.47068238]
# 	cost:= [95787.72324646]
# Epoch: 62
# Number of Samples: 1
# 	theta0:[1493.92399224]
# 	theta1:[1842.47068238]
# 	cost:= [112554.93230549]
# Epoch: 63
# Number of Samples: 1
# 	theta0:[1541.36973647]
# 	theta1:[1881.78287046]
# 	cost:= [18044.28306623]
# Epoch: 64
# Number of Samples: 1
# 	theta0:[1522.37274562]
# 	theta1:[1869.29913362]
# 	cost:= [89199.36812255]
# Epoch: 65
# Number of Samples: 1
# 	theta0:[1480.13547106]
# 	theta1:[1869.29913362]
# 	cost:= [108585.77086027]
# Epoch: 66
# Number of Samples: 1
# 	theta0:[1526.7371386]
# 	theta1:[1907.91194387]
# 	cost:= [18529.63510981]
# Epoch: 67
# Number of Samples: 1
# 	theta0:[1507.48635414]
# 	theta1:[1895.26142837]
# 	cost:= [83022.56440547]
# Epoch: 68
# Number of Samples: 1
# 	theta0:[1466.73771873]
# 	theta1:[1895.26142837]
# 	cost:= [104837.49264434]
# Epoch: 69
# Number of Samples: 1
# 	theta0:[1512.52799993]
# 	theta1:[1933.20194708]
# 	cost:= [18996.48429388]
# Epoch: 70
# Number of Samples: 1
# 	theta0:[1493.03621485]
# 	theta1:[1920.39305974]
# 	cost:= [77238.73308996]
# Epoch: 71
# Number of Samples: 1
# 	theta0:[1453.73259336]
# 	theta1:[1920.39305974]
# 	cost:= [101288.06714911]
# Epoch: 72
# Number of Samples: 1
# 	theta0:[1498.74105193]
# 	theta1:[1957.68578255]
# 	cost:= [19447.9195137]
# Epoch: 73
# Number of Samples: 1
# 	theta0:[1479.01902389]
# 	theta1:[1944.72559269]
# 	cost:= [71827.71023359]
# Epoch: 74
# Number of Samples: 1
# 	theta0:[1441.1171215]
# 	theta1:[1944.72559269]
# 	cost:= [97920.30182699]
# Epoch: 75
# Number of Samples: 1
# 	theta0:[1485.3710031]
# 	theta1:[1981.39309459]
# 	cost:= [19886.02731588]
# Epoch: 76
# Number of Samples: 1
# 	theta0:[1465.42807086]
# 	theta1:[1968.28773912]
# 	cost:= [66768.83748472]
# Epoch: 77
# Number of Samples: 1
# 	theta0:[1428.88526377]
# 	theta1:[1968.28773912]
# 	cost:= [94720.30298007]
# Epoch: 78
# Number of Samples: 1
# 	theta0:[1472.41003901]
# 	theta1:[2004.35112432]
# 	cost:= [20312.22182322]
# Epoch: 79
# Number of Samples: 1
# 	theta0:[1452.25453265]
# 	theta1:[1991.10607728]
# 	cost:= [62041.6278874]
# Epoch: 80
# Number of Samples: 1
# 	theta0:[1417.02907939]
# 	theta1:[1991.10607728]
# 	cost:= [91676.4697392]
# Epoch: 81
# Number of Samples: 1
# 	theta0:[1459.84881076]
# 	theta1:[2026.58528328]
# 	cost:= [20727.46829749]
# Epoch: 82
# Number of Samples: 1
# 	theta0:[1439.48832535]
# 	theta1:[2013.20553572]
# 	cost:= [57626.16152603]
# Epoch: 83
# Number of Samples: 1
# 	theta0:[1405.53949282]
# 	theta1:[2013.20553572]
# 	cost:= [88778.83316275]
# Epoch: 84
# Number of Samples: 1
# 	theta0:[1447.67708486]
# 	theta1:[2048.11954056]
# 	cost:= [21132.43401244]
# Epoch: 85
# Number of Samples: 1
# 	theta0:[1427.11866371]
# 	theta1:[2034.60972095]
# 	cost:= [53503.31007414]
# Epoch: 86
# Number of Samples: 1
# 	theta0:[1394.40679734]
# 	theta1:[2034.60972095]
# 	cost:= [86018.61923144]
# Epoch: 87
# Number of Samples: 1
# 	theta0:[1435.8841693]
# 	theta1:[2068.97668628]
# 	cost:= [21527.58971255]
# Epoch: 88
# Number of Samples: 1
# 	theta0:[1415.13442727]
# 	theta1:[2055.34114152]
# 	cost:= [49654.85362562]
# Epoch: 89
# Number of Samples: 1
# 	theta0:[1383.62098454]
# 	theta1:[2055.34114152]
# 	cost:= [83387.95739524]
# Epoch: 90
# Number of Samples: 1
# 	theta0:[1424.45919151]
# 	theta1:[2089.178513]
# 	cost:= [21913.27760947]
# Epoch: 91
# Number of Samples: 1
# 	theta0:[1403.52439864]
# 	theta1:[2075.42136341]
# 	cost:= [46063.53028601]
# Epoch: 92
# Number of Samples: 1
# 	theta0:[1373.17195878]
# 	theta1:[2075.42136341]
# 	cost:= [80879.6839582]
# Epoch: 93
# Number of Samples: 1
# 	theta0:[1413.3912785]
# 	theta1:[2108.74594261]
# 	cost:= [22289.75678511]
# Epoch: 94
# Number of Samples: 1
# 	theta0:[1392.27741728]
# 	theta1:[2094.87111952]
# 	cost:= [42713.04432669]
# Epoch: 95
# Number of Samples: 1
# 	theta0:[1363.04967555]
# 	theta1:[2094.87111952]
# 	cost:= [78487.20742877]
# Epoch: 96
# Number of Samples: 1
# 	theta0:[1402.66967238]
# 	theta1:[2127.69911689]
# 	cost:= [22657.23337738]
# Epoch: 97
# Number of Samples: 1
# 	theta0:[1381.38247746]
# 	theta1:[2113.7103888]
# 	cost:= [39588.04931125]
# Epoch: 98
# Number of Samples: 1
# 	theta0:[1353.24422972]
# 	theta1:[2113.7103888]
# 	cost:= [76204.41450334]
# Epoch: 99
# Number of Samples: 1
# 	theta0:[1392.2838031]
# 	theta1:[2146.05746389]
# 	cost:= [23015.88053945]

# %%
plt.plot(iteration,loss)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
