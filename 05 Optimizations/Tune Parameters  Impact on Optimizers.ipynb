# %%
'''
Learning Rate : 

plot for the lr : [1.0, 0.1, 0.01, 0.001, 0.0001, 1e-05, 1e-06, 1e-07]

The plots show oscillations in behavior for the too-large learning rate of 1.0 
and the inability of the model to learn anything with the too-small learning rates of 1E-6 and 1E-7.

Where there is a too small learning rate leads to no learnig

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''

Momentum :
    - values : [0.0, 0.5, 0.9, 0.99]
    
    - We can see that the addition of momentum does accelerate the training of the model.
    
    - momentum values of 0.9 and 0.99 achieve reasonable train and test accuracy within about 50 training epochs
    
    - the accuracy of the model on the holdout test dataset appears to be more stable, 
     - showing less volatility over the training epochs.

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Effect of Learning Rate Schedules

# %%
'''

# Learning Rate Decay

    - Calculate learning rates for Values [0.1, 0.01, 0.001, 0.0001] and updates = 200 and int_lrate = 0.01
    - The learning rate starts at the initial value of 0.01
    - At a small decay value of 0.0001 (red) has almost no effect
    - A large decay value of 0.1 (blue) has a dramatic effect,also
    - decay value of 0.1 reducing the learning rate to below 0.002 within 50 epochs and arriving at the final value 
      of about 0.0004
     
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
decays = [1E-1, 1E-2, 1E-3, 1E-4]

# %%
decays
# Out:
# [0.1, 0.01, 0.001, 0.0001]

# %%
'''
    Decays
        - We can see that the large decay values of 0.1 and 0.01 indeed decay the learning rate too rapidly 
          for this model on this problem and result in poor performance.
        - The smaller decay values do result in better performance,
'''

# %% [markdown]
# ![image.png](attachment:image.png)
