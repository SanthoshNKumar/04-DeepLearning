# %%
'''
Batch Gradient Descent:Weights are updated after computing the gradient of error with respect to the entire training set

Issues :
    - It consider complete or whole datset while computing the weights. so it is slow
    - Does't allow update model online
    - Memory and computation Issue  if dataset is huge
'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
 Weight Updates:

    theta0 = theta0 - (learningrate * dtheta0)
    theta1 = theta1 - (learningrate * dtheta1)

'''

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

x = [30, 35, 37, 59, 70, 76, 88, 100 ]
y = [1100, 1423, 1377, 1800, 2304, 2588, 3495, 4839]

x = np.reshape(x,(-1,1))
y = np.reshape(y,(-1,1))

scaler = MinMaxScaler()
scaler.fit(x)
x = scaler.transform(x)

n = len(y)
learningrate = 0.1

# %%
print("In Batch Gradient Descent Weights are updating after considering all the samples in dataset for finding \nprediction and cost value generation")


theta0 = 0
theta1 = 0

loss = []
iteration = []

for i in range(100):
    
    if (i %25 ==0):
        print("Epoch:",i)
        print("Number of Samples:",len(x))
            
        print("\ttheta0:{0} \n\ttheta1:{1}".format(theta0,theta1))

    predicted = theta0 + (theta1 * x)

    cost =(1/n)*np.sum(np.square(y - predicted))
    
    if (i %25 ==0):
        print("\tcost:",cost)
    
    loss.append(cost)
    iteration.append(i)

    dtheta0 = (-(2/n) * np.sum(np.subtract(y,predicted)))
    dtheta1 = (-(2/n) * np.sum(np.multiply(np.subtract(y,predicted),x)))

    theta0 = theta0 - (learningrate * dtheta0)
    theta1 = theta1 - (learningrate * dtheta1)
# Out:
# In Batch Gradient Descent Weights are updating after considering all the samples in dataset for finding
# prediction and cost value generation
# Epoch: 0
# Number of Samples: 8
# 	theta0:0
# 	theta1:0
# 	cost: 7001020.5
# Epoch: 25
# Number of Samples: 8
# 	theta0:1575.6045390825343
# 	theta1:1876.3431547071684
# 	cost: 373386.39951716224
# Epoch: 50
# Number of Samples: 8
# 	theta0:1313.4100632390318
# 	theta1:2399.5111699947847
# 	cost: 234956.45791982568
# Epoch: 75
# Number of Samples: 8
# 	theta0:1153.2130394844576
# 	theta1:2716.5415978596106
# 	cost: 183954.9424979196

# %%
plt.plot(iteration,loss)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid()
