# %%
'''
Keras Architecture
    - 
The functional API, can be used to define much more complex models that are non-sequential, including

    - Multi-input models
    - Multi-output models
    - Models that are both multiple input and multiple output
    - Directed acyclic graphs
    - Models with shared layers

'''

# %%
'''
Multilayer Perceptron : Define a multilayer Perceptron model 

'''

# %% [markdown]
# ![01_multilayer_perceptron_graph.jpg](attachment:01_multilayer_perceptron_graph.jpg)

# %%
'''
Convolutional Neural Network :
    Define a convolutional neural network for image classification.

'''

# %% [markdown]
# ![03_convolutional_neural_network.jpg](attachment:03_convolutional_neural_network.jpg)

# %%
'''
Recurrent Neural Network : The model expects 100 time steps of one feature as input. 

'''

# %% [markdown]
# ![02%20recurrent_neural_network.jpg](attachment:02%20recurrent_neural_network.jpg)

# %%
'''
Shared Layers Model

    01 Shared Input Layer : Multiple layers can share the output from one layer.
    02 Shared Feature Extraction Layer :

'''

# %% [markdown]
# '''
# Shared Layers Model
#
#
# 01 : Shared Input Layer
#
# '''

# %% [markdown]
# ![04_shared_input_layer.jpg](attachment:04_shared_input_layer.jpg)

# %%
'''
Shared Layers Model

02 : Shared Feature Extraction Layer

'''

# %% [markdown]
# ![05_shared_feature_extractor.jpg](attachment:05_shared_feature_extractor.jpg)

# %%
'''
Multiple Input and Output Models
'''

# %%
#01 Multiple Input Model

# %% [markdown]
# ![06_multiple_inputs.jpg](attachment:06_multiple_inputs.jpg)

# %%
#02 Multiple Output Model

# %% [markdown]
# ![07_multiple_outputs.jpg](attachment:07_multiple_outputs.jpg)
