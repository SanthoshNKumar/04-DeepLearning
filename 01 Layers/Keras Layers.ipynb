# %%
'''
Layer is a callable objects that takes as input one or more tensors and that outputs one or more tensors.

'''

# %%
'''
Keras Layers
    - Core layers
    - Convolutaional Layers
    - Pooling layers
    - Activation Layers
    - Dropout Layers
    - Locally- Connected layers
    - Recurrent Layer
    - Embedding Layer
    - Normalization Layer
    - Noise Layer
    - Merge Layer
    - Layer Maethods
'''

# %%
'''

Core Layers
    - Dense
    - Flattern
    - Dropout
    - Reshape
    - Permute
    - RepeatVector
    - Lambda
    - Pooling
    - Locally Connected Layer

'''

# %%
'''
Convolutional Layers
    - Conv1D : 1D convolution layer 
    - Conv2D : 2D convolution layer 
    - Conv2D Transpose
    - Conv3D : 3D convolution layer 
    - Conv3D Transpose
    - ConvLSTM2D 
    - SeparableConv1D
    - SeparableConv2D
    - DepthwiseConv2D
    - UpSampling1D
    - UpSampling2D
    - UpSampling3D
    - ZeroPadding1D
    - ZeroPadding2D
    - ZeroPadding3D
    - Cropping1D
    - Cropping2D
    - Cropping3D

'''

# %%
'''
Pooling Layer
    - MaxPooling1D
    - MaxPooling2D
    - MaxPooling3D
    - AveragePooling1D
    - AveragePooling2D
    - AveragePooling3D
    - GlobalMaxPool1D
    - GlobalMaxPool2D
    - GlobalMaxPool3D
'''

# %%
'''
Activation Layer

    - ReLu
    - LeakyReLU
    - PReLU 
    - ELU
    - Softmax
    - ThresholdedReLU
'''

# %%
'''
Dropout Layer

    - Dropout
    - SpatialDropout1D
    - SpatialDropout2D
    - SpatialDropout3D
'''

# %%
'''
Recurrent Layer

    - SimpleRNN
    - GRU
    - CuDNNGRU
    - LSTM
    - CuDNNLSTM
'''

# %%
'''
Embedding Layer

    - Embedding
'''

# %%
'''
Normalization Layer

    - BatchNormalization
    
'''

# %%
'''
Noise Layer

    - GaussianNoise
    - GaussianDropout
    - AlphaDropout
    
'''

# %%
'''
Merge Layer

    - Add
    - Subtract
    - Multiply
    - Average
    - Maximum
    - Minimum
    - Concatenate
    - dot
    
'''

# %%
'''
Layer Wrapppers
    - Bidirectional

'''

# %%
'''
Layer Methods
    model.add
    model.add_loss
    model.add_metric
    model.add_update
    model.add_variable
    model.add_weight
    model.apply

    model.build
    model.built

    model.call
    model.compile
    model.compute_mask
    model.compute_output_shape
    model.compute_output_signature
    model.count_params

    model.evaluate
    model.evaluate_generator

    model.fit
    model.fit_generator
    model.from_config

    model.get_config
    model.get_input_at
    model.get_input_mask_at
    model.get_input_shape_at
    model.get_layer
    model.get_output_at
    model.get_output_mask_at
    model.get_output_shape_at
    model.get_updates_for
    model.get_weights

    model.inbound_nodes
    model.input
    model.input_mask
    model.input_shape
    model.input_spec
    model.inputs

    model.layers
    model.load_weights
    model.losses

    model.metrics
    model.

    model.name
    model.name_scope
    model.non_trainable_variables
    model.non_trainable_weights

    model.optimizer
    model.outbound_nodes
    model.output
    model.output_mask
    model.output_names
    model.output_shape
    model.outputs
    model.pop

    model.predict
    model.predict_classes
    model.predict_generator
    model.predict_on_batch
    model.predict_proba

    model.reset_metrics
    model.reset_states
    model.run_eagerly

    model.sample_weights
    model.save
    model.save_weights
    model.set_weights
    model.state_updates
    model.stateful
    model.submodules
    model.summary
    model.supports_masking

    model.test_on_batch
    model.to_json
    model.to_yaml
    model.train_on_batch
    model.trainable
    model.trainable_variables
    model.trainable_weights

    model.updates

    model.variables

    model.weights
    model.with_name_scope
'''
