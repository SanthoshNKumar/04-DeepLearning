# %%
'''

Transfer Learning is an approach where we use one model trained on a machine learning task and reuse it as a 
starting point for a different job.

Transfer Learning approach will involve using layers that have been pre-trained on a source task to solve a target task.

Typically download some pre-trained model and "cut off" its top portion (the fully-connected layer), leaving us with only 
the convolutional and pooling layers.

Using the pre-trained layers, we'll extract visual features from our target task/dataset

When using these pre-trained layers, we can decide to freeze specific layers from training.

We'll be using the pre-trained weights as-they-come and not updating them with backpropagation

'''

# %%
'''
Building Blokcs of CNN

    1. Convolutional Layer:
            - Number of filters;Filter size
    2. ReLu (Activation) Layer
    3. Pooling Layer:
    4. Fully-Connected Layer:

'''

# %% [markdown]
# ![Building%20Blocks_CNN.PNG](attachment:Building%20Blocks_CNN.PNG)

# %%
'''
Different taks in Computer Vision Field
    - Semantic Segmentation
    - Image Classification
    - Object Detection
    - Image Generation
    - Denoising
    - Super-Resolution
    - 3D Face Animation
    - Activity Recognition
    - Facial Recognition and Modelling
    - Optical Character Recognition
    - Object Tracking
    - Visual Question Answering
    - Object Recognition
    - Style Transfer
    - Image Captioning
    - Image Reconstruction
    - Emotion Recognition
'''

# %%
'''
Types of Object Recognization
    - Image Classificaton
    - Object Detection
    - Instance Segmentation

'''

'''
Image Data Augmentation
    - Image rotation
    - Image Translation
    - Horizontal Flip
    - Zooming into the image


'''

# %% [markdown]
# ![CNN_Types_Of%20Object%20Recognization.png](attachment:CNN_Types_Of%20Object%20Recognization.png)

# %%
'''
Popular Datset vailable for Computer Vision

    - Computer Vision
        1. MNIST : (Modified National Institute of Standards and Technology)
        2. Fashion-MNIST
        2. ImageNet  : 
            - Dataset is used in the  ImageNet Large Scale Visual Recognition Challenge (ILSVRC)
        3.CIFAR : Canadian Institute for Advanced Research
        4.COCO : Microsoft Common Objects in Context
        5.CIFAR-10,100 (10,100 classed)
'''

# %%
'''
one-stage detector :

one-stage detector:requires only a single pass through the neural network and predicts all the bounding boxes in one go.

'''

# %%
'''

Pretarined Modules for Object Detection,Image Classification and Segmentation :

    Object Detection Models
        - R-CNN (Regions with CNN ) 
        - Faster R-CNN
        - YOLO V1, V2,V3,V4
        - Mask R-CNN
        - SSD : (single-stage object detection)
        - RetinaNet
        - Dynamic R-CNN
        
    Image Classification Models
        - EfficientNet B0
        - ResNet 10,18,34,50,101    # Residual Network 
        - VGG 16,19
        - DarkNet V1,V2
        - MobileNet V1,V2
        - GoogLeNet
        - SqueezeNet
        - DenseNet121
    
    Segmentation
        - MaskRCNN
        - UNET
'''

# %%
'''
Pretarined Modules for Convolutional Neural Networks(CNN)

     Convolutional Neural Networks are used to extract features from images (and videos), employing convolutions 
     as their primary operator.
     Image Models that build representations of images for downstream tasks such as classification and object detection.

Popular State of the Art Deep CNN Models
    - AlexNet
    - VGG-16,19 
    - Inception
    - Inception-V2,V3,V4
    - ResNet
    - DenseNet
    - MobileNet-V1
    - GoogleNet
    - Xception
    - Fast YOLO V3
    - Fast OCR
    - Fast YOLO V4-SmallObj
    
***
VGG : Visual Geometry Group
'''

# %%
'''
What is VGG?

VGG16 is a convolutional neural network trained on a subset of the ImageNet dataset.

In the 2014 ImageNet Classification Challenge, VGG16 achieved a 92.7% classification accuracy. 
But more importantly, it has been trained on millions of images.


Architecture of VGG
    - 16 Convolutional and Max Pooling layers.
    - 3 Dense layers for the Fully-Connected layer
    - output layer of 1,000 nodes.


How to Utilize the VGG16 Model?
    1.Feature Extraction Approach
    2.Fine-Tuning Approach


'''

# %% [markdown]
# ![Transfer%20Learning_CNN_VGG%20Architecture.PNG](attachment:Transfer%20Learning_CNN_VGG%20Architecture.PNG)

# %%
'''
Different taks in NLP
    - Machine Translation
    - Question Answering
    - Language Modelling
    - Text Classification
    - Sentiment Analysis
    - Text Geneation
    - Text Summarization
        - Extractive Summarization.
        - Abstractive Text Summarization
    - Named Entity Recognition
    - Visual Question Answering
    - Information Retrieval
    - Dialogue
    - Part-Of-Speech Tagging
    - Topic Models
    - Chatbot
    - Hate Speech Detection
    - Intent Detection
    - Morphological Analysis
    - Speech-to-Text Translations
'''

# %%
'''
Popular Datset vailable for NLP 
    
    - NLP
        1. Question Answering
            1. SQuAD : (Stanford Question Answering Dataset)
            2. GLUE (General Language Understanding Evaluation benchmark)
            3. Natural Questions
            4. NewsQA : Documents are CNN news articles.
            5. WebQuestions 
            
        2. Sentimen Analysis 
            1. IMDb :Internet Movie Database (Movie review)
            2. SST (Stanford Sentiment Treebank)
        
        3. NER :
        
        4. Language Modeling:
            1. WikiText -2
            2. WikiText - 103
            3. XQuada
'''

# %%
'''
Pre-Trained Language Models that have accelerated natural language processing applications in the real world.

Multi Purpose NLP Modules

    1. OpenAI’s GPT-3
    2. Google’s BERT
    3. Microsoft’s CodeBERT
    4. ELMo
    5. XLNet : Extension of the Transformer-XL model
    6. Google’s ALBERT
    7. ULMFiT
    8. Facebook’s RoBERTa
'''

# %%
'''
Pretrained Named Entity Recognition (NER) Modules
    1. Stanford Core NLP
    2. Spacy NER
    3. Polyglot
    4. Flair
    5. Deep Pavlov
    6. Allen NLP
'''

# %%
'''
Word Embedding Types 
    - Static Word Embedding
    - contextual word Embedding 
        - Context2Vec
        - ElMo
        - CoVe
'''
'''
Pretrained Word Embeddings Models

    - Glove : (Global Vectors for Word Representation) by Stanford  
    - Word2vec : 1000 billion words from Google News
        - Continuous Bag-of-Words
        - Skip-gram
    - FastText
        - Fast Text Continuos bag of Word
        - Fast Text Skipgram
    - ELMo : Embeddings from Language Models
    - Gensim : 

'''

# %%
'''
Transformers :

    - BERT
    - RoBERT
    - XLNet
    - ALBERT
    - BART
    - GPT
    - T5
    - XML
    - ELECTRA
    - ViBERT
    - VideoBERT
'''

# %%
'''
Keras Applications are deep learning models that are made available alongside pre-trained weights. 
These models can be used for prediction, feature extraction, and fine-tuning

The following image classification models (with weights trained on ImageNet) are available:
    Xception
    VGG16
    VGG19
    ResNet50
    InceptionV3
    InceptionResNetV2
    MobileNet
    MobileNetV2
    DenseNet
    NASNet
'''
