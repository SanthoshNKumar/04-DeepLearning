# %%
'''
Difffrence Between 'Image Processing' and 'Computer Vision'

Image Processing
    - It focus on processing images
    - Input and output both are image
    - Transofrm imgaes in many ways
        - Smoothing
        - Sharping
        - Changing the brightness and contrast
        - Highligthng the edges


Computer Vision
    - It Foucs on Making sense of what a machine sees
    - Input is image and output is task specific knowledge,such as Object Labels

'''

# %%
'''
Terminilogies

1. Imgage Classifcation : 
    - Image Classification helps us to classify what is contained in an image.

2. Localization : Identify the location of a single object in the given image

3. Object Detection : 
    - Object Detection specifies the location of multiple objects in the image.
    - We can predict the location along with the class for each object using Object Detection.

4. Image Segmentation : 
    - Image is a collection or set of different pixels.
    - We group together the pixels that have similar attributes using image segmentation
    - Segmentation will create a pixel wise mask of each object in the images.
    
    
Object Detection is more complex than the Object Classification, basically Object Classification also recognize objects but it 
does not tell us where it is located in the image and more ever object classifcation does not work in the image where we have 
more than one objects.
it mean if image have more than one Object, Object cassification will not work.


'''

# %% [markdown]
# ![DL_Computer%20Vision_Image%20Recognization.png](attachment:DL_Computer%20Vision_Image%20Recognization.png)

# %%
'''
Dataset
    - ImageNet
    - CIFAR
    
CIFAR-10 :  This dataset contains 60, 000 32×32 color images in 10 different classes 
            (airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks) etc
'''

# %%
'''
ImageNet is a dataset of Over 15 million High resolution Images belongs to different 22000 categories.

'''

# %%
'''
What is Stride?
What is Padding?

'''

# %%
'''

Formaula for finding output of the layers in the CNN

1. Layer without padding 
 ((n - f) / s ) + 1  *  ((n - f) / s ) + 1 

      n = Image size (ex : 227 )
      f = filter size 
      s = stride

2. Layer with padding
  ((n + 2p - f) / s ) + 1  *  ((n + 2p - f) / s ) + 1 
  
  n = Image size (ex : 227 )
  p = padding
  f = filter size 
  s = stride
    
'''

# %%
'''
List of Pretrained Model in Computer Vision

'''

'''
01. Image Classifcation
        - AlexNet
        - VGG 16,19
        - ResNet
        - Inception
        - EfficientNet

02. Object Detection : Region proposals
        - R-CNN   
        - Fast R-CNN
        - Faster R-CNN
        - SSD (Single Shot Detector)
        - YOLO (You Only Look Once)

03. Image Segmentation
        - MASK RCNN


'''

# %% [markdown]
# ![Tranfer%20Learning%20Architecture%20from%202012%20to%202017%20.PNG](attachment:Tranfer%20Learning%20Architecture%20from%202012%20to%202017%20.PNG)

# %%
'''

AlexNet
    - Alexnet won the Imagenet large-scale visual recognition challenge in 2012
    - AlexNet architecture consists of 5 convolutional layers, 3 max-pooling layers, 2 normalization layers, 
      2 fully connected layers, and 1 softmax layer.
    - Each convolutional layer consists of convolutional filters and a nonlinear activation function ReLU
    - The pooling layers are used to perform max pooling. 
    - Input size is fixed due to the presence of fully connected layers.
    - AlexNet overall has 60 million parameters.
    - Batch size of 128 
    - SGD Momentum as learning algorithm 
    - Heavy Data Augmentation with things like flipping, jittering, cropping, color normalization, etc. 
    - AlexNet was trained on a GTX 580 GPU with only 3 GB of memory which couldn’t fit the entire network.
      So the network was split across 2 GPUs, with half of the neurons(feature maps) on each GPU. 
      
'''

# %%
'''
VGG 16 : 
    - VGG : Visual Geometry Group
    - It is also called the OxfordNet model, named after the Visual Geometry Group from Oxford.
    - Number 16 refers that it has a total of 16 layers that has some weights.
    - It Only has Conv and pooling layers in it.
    - always use a 3 x 3 Kernel for convolution.
    - 2x2 size of the max pool.
    - has a total of about 138 million parameters.
    - Trained on ImageNet data
    - It has an accuracy of 92.7%.
    - it has one more version of it Vgg 19, a total of 19 layers with weights.

'''

# %% [markdown]
# ![Transfer%20Learning_CNN_VGG%20Architecture.PNG](attachment:Transfer%20Learning_CNN_VGG%20Architecture.PNG)

# %%
'''
Architecture of 'VGG'

    Total Layer : 16

    Input : 224*224*3
    
    13 Convolution Layer
    1 Flattern Layer
    2 Dense Layer
    
    VGG 16 Having 6 Blocks
        1. 1st Block hvaing 2 CONV Layer and 1 Max Pooling
        2. 2nd Block hvaing 2 CONV Layer and 1 Max Pooling
        3. 3rd Block hvaing 3 CONV Layer and 1 Max Pooling
        4. 4th Block hvaing 3 CONV Layer and 1 Max Pooling
        5. 5th Block hvaing 3 CONV Layer and 1 Max Pooling
        6. 6th Block Having 2 Flattern and 2 Dence Layer

    All the Convolution layer
        - Filter size : 3X3
        - Stride = 1
        - Padding = same
        
    Max pooling 
        - Filter size :2x2 
        - stride =2 

    Output : (1,1000)
'''

# %%
'''
Inception :
    - In Inception network become Wider insted of Deeper.
    - The original incarnation of this architecture was called GoogLeNet,
    - The goal of the inception module is to act as a “multi-level feature extractor”.
    - computing 1×1, 3×3, and 5×5 convolutions within the same module of the network.
    - The output of the above filters are then stacked along the channel dimension and before being fed into the next layer 
      in the network.
      
Inception popular versions 
    1. Inception v1.
    2. Inception v2 and Inception v3.
    3. Inception v4 and Inception-ResNet.


'''

# %%
'''
An Inception Module consists of the following components:

Input layer
1x1 convolution layer
3x3 convolution layer
5x5 convolution layer
Max pooling layer
Concatenation layer

'''

# %% [markdown]
# ![Transfer%20Learing_Inception_Dog.png](attachment:Transfer%20Learing_Inception_Dog.png)

# %%
'''
Why Need of Inceptions?

In the above image with a dog, The area occupied by the dog is different in each image.
Because of this huge variation in the location of the information, choosing the right kernel size for the convolution 
operation becomes tough.

A larger kernel is preferred for information that is distributed more globally, and a smaller kernel is preferred for 
information that is distributed more locally.

Very deep networks are prone to overfitting. It also hard to pass gradient updates through the entire network.

Naively stacking large convolution operations is computationally expensive.

In Inception perform convolution on an input, with 3 different sizes of filters (1x1, 3x3, 5x5).
Additionally, max pooling is also performed. The outputs are concatenated and sent to the next inception module.

'''

# %%
'''
Moudles of Inception Version V1
    - Nive Version of Inception
    - Dimension Reduction

'''

# %%
'''
Logic Behind Inception (Nive Version)

    - It has 3 Convolution net work and 1 Max Pooling
    - Every layer having diffeent size filter
    - finally Concating all the layer 
    
Idea is that Model will learn from Paraller Filtres of different sizes with multiple scale.

Why many Filters :
 If look ate the images object or Information area many vary image to image.
 In images there is huge varibation in the area of Information.Because of this it is defficut to choose the right size filter
 

'''

# %% [markdown]
# ![Tranfer%20Learning%20Architecture%20basic%20Inception%20.PNG](attachment:Tranfer%20Learning%20Architecture%20basic%20Inception%20.PNG)

# %%
'''
- 2nd Module of Inception version1 is Dimension Reduction
    - Normal Issue 
        - Issue with Deeper Neural network is Overfitting
        - When there is more parameters  it means more computation resources
        
    - Using Inception we reduce the number of parameters means Data is less and less parameters
    - CHnages on the Naive Inception to implement is 
        - We are adding extract 1*1 Convolution before 3*3 Conv and before 5*5 Conv and adding 1*1 Conv after Max Pooling


'''

# %% [markdown]
# ![Tranfer%20Learning%20Incpetion%20Dimention%20Reduction.PNG](attachment:Tranfer%20Learning%20Incpetion%20Dimention%20Reduction.PNG)

# %%
'''
Architectural Changes in Inception V2:

In the Inception V2 architecture. The 5×5 convolution is replaced by the two 3×3 convolutions. 
This also decreases computational time and thus increase computational speed because a 5×5 convolution is 2.78 more expensive 
than 3×3 convolution. So, Using two 3×3 layers instead of 5×5 increases the performance of architecture.


This architecture also converts nXn factorization into 1xn and nx1 factorization. \
As we discuss above that a 3×3 convolution can be converted into 1×3 then followed by 3×1 convolution which is 33% cheaper 
in terms of computational complexity as compared to 3×3.

'''

# %%
'''
Inception v3: 

Inception v3 is almost similar to Inception v2 except for some updates. Those updates are listed below:
    - Use of RMSprop optimizer.
    - Batch Normalization in the fully connected layer of the Auxiliary classifier.
    - Use of 7×7 factorized Convolution.
    - Label Smoothing Regularization(a method to regularize the classifier by estimating the effect of label-dropout 
      during training). It prevents the classifier to predict too confidently a class. The addition of label 
      smoothing gives 0.2% improvement from the error rate.

'''

'''

Inception v4: 

The main motto behind creating inception v4 is to reduce the complexity of inception v3 and make the module more uniform.

'''

# %%
'''
Inception v3: 
    It has total 48 Layers
    Input Size = 299*299*3
    The pretrained network can classify images into 1000 object categories
    Changes on Inception V1 to make Inception V3
        - Factorization Convolution into Smaller Convolution
        - Factorization Into Asymmetic Convolutions
        
*** Factorization Convolution   ex:  In the network instead of 5*5 Conv we going to use two 3*3 Conv

Why Factorization Convolution?
    - Mainly yo Reduce the parameters
        Ex: if multiple 5* 5 we get 25, bu if multipl 3*3 we get 9 again 3* 3 we get 9 so totally 18
            By using one 5 by 5 Conv we were getting 25 Parameters and with two 3 by 3 Conv getting 18 Parameres
            Number of parameters are reduced by 28%
            
            
            
*** Factorization Into Asymmetic Convolutions
    
    We have Conv of 3*3
    Now we are Factorization one (3*3) Conv into two Asymmetic Convolutions (1*3) and (3*1)
    With Using Asymmetic Convolutions we are also reducing parameters
    with this we rduced number of paramers into 33%

'''

# %% [markdown]
# ![Transfer%20Learing_Inception_Factorization.png](attachment:Transfer%20Learing_Inception_Factorization.png)

# %%
'''
Reduction Block :
    - Inception v4 introduced specialized “Reduction Blocks” which are used to change the width and height of the grid. 
      The earlier versions didn’t explicitly have reduction blocks, but the functionality was implemented.
      

'''

# %%
'''
GoogLeNet :

GoogLeNet is a 22-layer deep convolutional neural network that's a variant of the Inception Network
'''

# %%
'''
ResNet:(Residual Network)
    - Won 1st place in the ILSVRC 2015 classification competition with top-5 error rate of 3.57% 
    - Won the 1st place in ILSVRC and COCO 2015 competition in ImageNet Detection, ImageNet localization, Coco detection 
      and Coco segmentation
    - ResNet, which was proposed in 2015 by researchers at Microsoft Research introduced a new architecture called Residual 
      Network.
    - Residual Network some where address vanishing/exploding Gradient problem.
    - Resnet use the concept of Skip connection. using this 'skip connection' or 'Identity mapping' we can addess the 
      problem of Vanishing Gradinet Problem.


    Skip Connection : Normally Convolution layer are stcked one after the After , but in Resnet layers are stcked one after 
    other also add original input to the output of Convolution.

    Traditional : Yhat = F(x)

    Skip connection = Yhat = F(x) + x

    Here main goal of to make F(x) = 0
    so we can achive Yhat = x
    
    
    RenNet 50 : 
        - ResNet50 is a variant of ResNet model which has 48 Convolution layers along with 1 MaxPool and 1 Average Pool layer
        
    Variants of ResNets
        - ResNeXt
        - DenseNet : Densely Connected CNN
        
    ResNets:
        - ResNet V1
        - ResNet V2
            - ResNet50 
            - ResNet101
            - ResNet152
            - ResNet50V2
            - ResNet101V2
            - ResNet152V2

'''

# %% [markdown]
# ![Tranfer%20Learning%20Resnet_SkipConnection.PNG](attachment:Tranfer%20Learning%20Resnet_SkipConnection.PNG)

# %%
'''
Architecture 'Resnet 50'

'''

# %% [markdown]
# ![Tranfer%20Learning%20Architecture%20of%20ResNet50_1.png](attachment:Tranfer%20Learning%20Architecture%20of%20ResNet50_1.png)

# %%
# Architecture Diff in 'ResNet-V1' and 'ResNet-V2'

# %% [markdown]
# ![Tranfer%20Learning%20diff%20between%20ResNetV1%20and%20ResnetV2.png](attachment:Tranfer%20Learning%20diff%20between%20ResNetV1%20and%20ResnetV2.png)

# %%
'''
DenseNet :(Dense Convolutional Network):

A DenseNet is a type of convolutional neural network that utilises dense connections between layers.
through Dense Blocks, where we connect all layers (with matching feature-map sizes) directly with each other. 

'''
# Out:
# '\nDenseNet :(Dense Convolutional Network)\n\n'

# %% [markdown]
# ![Tranfer%20Learning%20What%20is%20DenseNet.PNG](attachment:Tranfer%20Learning%20What%20is%20DenseNet.PNG)

# %%
'''
Difference Betwen CNN and R-CNN?

A typical CNN can only tell you the class of the objects but not where they are located.
It is actually possible to regress bounding boxes directly from a CNN but that can only happen for one object at a time

If multiple objects are in the visual field then the CNN bounding box regression cannot work well due to interference.
 
The regions in the R-CNN are detected by selective search algorithm followed by resizing so that the regions 
are of equal size before they are fed to a CNN for classification and bounding box regression.

The RCNN algorithm proposes a bunch of boxes in the image and checks if any of these boxes contain any object. 
RCNN uses selective search to extract these boxes from an image (these boxes are called regions).

'''

# %%
'''

How Selective Search algorithm works?

There are basically four regions that form an object: varying scales, colors, textures, and enclosure.
Selective search identifies these patterns in the image and based on that, proposes various regions.


Selective search algorithm : 
    It Works by generating sub-segmentations of the image that could belong to one object — 
    based on color, texture, size and shape — and iteratively combining similar regions to form objects. 
    
    
Selectoive Search Algorithm:
Generate initial sub-segmentation of input image.
Combine similar bounding boxes into larger ones recursivel
Use these larger boxes to generate region proposals for object detection.

'''

# %%
'''
R-CNN :

Proposed a method where we use selective search to extract just 2000 regions from the image and  called them region proposals.

How it identify Object?
    1  Input Image
    2  Extract Regions Propasal (2000)
    3. Wrapped Regions send to CNN 
    4. Classify Regions
    
    
1.Input Image selective search algorithm
2.2000 candidate region proposals are warped into a square and fed into a convolutional neural network that produces
   a 4096-dimensional feature vector as output. 
3.The CNN acts as a feature extractor and the output dense layer consists of the features extracted from the image and 
  the extracted features are fed into an SVM to classify the presence of the object within that candidate region proposal.    

'''

# %%
'''
Problem with R-CNN
    1. It takes a huge amount of time to train the network as you would have to classify 2000 region proposals per image.
    2. It cannot be implemented real time as it takes around 47 seconds for each test image.
    3. The selective search algorithm is a fixed algorithm.
       Therefore no learning is happening at that stage. This could lead to the generation of bad candidate region proposals
'''

# %%
'''
Fast R-CNN:



'''

# %%
'''
Probelm with R-CNN and Fast R-CNN?

Both of the above algorithms(R-CNN & Fast R-CNN) uses selective search to find out the region proposals.
Selective search is a slow and time-consuming process affecting the performance of the network.

So in faster RCNN Came up with an object detection algorithm that eliminates the selective search algorithm and 
lets the network learn the region proposals.

'''

# %%
'''
Region Proposel Network (RPN) :
RPN is small neural network sliding on the last feature map of the convolution layers and predict wether there 
is an object or not and also predict the bounding box of those objects.

'''

# %%
'''
How faster CNN is differ from fast RCNN?
    - No selective search algorithm  for region propasal
    - Instead of using selective search algorithm on the feature map to identify the region proposals, 
      a separate network is used to predict the region proposals.
    - The predicted region proposals are then reshaped using a RoI pooling layer which is then used to
      classify the image within the proposed region and predict the offset values for the bounding boxes.


Faster RCNN is the modified version of Fast RCNN. The major difference between them is that Fast RCNN uses selective 
search for generating Regions of Interest, while Faster RCNN uses “Region Proposal Network”, aka RPN.

'''

# %% [markdown]
# ![Tranfer%20Learning%20DiffBwCNN_RCNN_FRCNN_FtrRCNN.png](attachment:Tranfer%20Learning%20DiffBwCNN_RCNN_FRCNN_FtrRCNN.png)

# %%
'''
YOLO : You Only Look Once

    - It means that algorithms only looks at the image only once, which means that only one forward propagtion pass through 
      the neural network to make the prediction.
    - It is used for object Detection.
    - Finding what and where in the image, means what objects are indie the given image and where they are in the image.
    - In YOLO we draw Bounding Boxes across the objects 
    
Bounding Boxes are described using four descriptors
    - Center of the bounidng box (bx.by)
    - Width(bw)
    - Height(bh)
    - c class of an object
    
Yolo will draw grid on the image, YOLO generally uses 19*19 grid


# Understsing the grid cell

3 Object = [bus,car,truck]

y = [1,bx,by,bh,bw,0,1,0]

    1 means there ia on object
    bx,by = center of the bounding box
    bh and bw = height and width of the bounding box
    last 3 (0,1,0) = mean object class = [bus,car,truck] means this is car object or class


# Intersection and Union(IOU)

IOU is computed based on 2 bounidng block

IOU = Size of the Intersection / Size of the Union

IOU >= 0.5  "Correct prediction" 

'''

# %% [markdown]
# ![Tranfer%20Learning%20YOLO_IOU.PNG](attachment:Tranfer%20Learning%20YOLO_IOU.PNG)

# %% [markdown]
# ![Tranfer%20Learning%20YOLO_Non%20Max%20Supression%20Bounidng%20Boxes.PNG](attachment:Tranfer%20Learning%20YOLO_Non%20Max%20Supression%20Bounidng%20Boxes.PNG)

# %%
'''
Non-Max suppression :

The objects in the image can be of different sizes and shapes, and to capture each of these perfectly, 
the object detection algorithms create multiple bounding boxes. above image (left image)

Ideally, for each object in the image, we must have a single bounding box. Something like the image on the right.

To select the best bounding box, from the multiple predicted bounding boxes, these object detection algorithms use 
non-max suppression. 

This technique is used to “suppress” the less likely bounding boxes and keep only the best one.

'''

'''
Algorithms that use non-max suppression?

    - SSD, YOLO (You Only Look Once)


'''

# %%
'''
Anchor Boxes :
    - These are Predefined bounding box of a certain height and width
    - During detection, the predefined anchor boxes are tiled across the image. 
      The network predicts the probability and other attributes, such as background, intersection over union (IoU) and 
      offsets for every tiled anchor box.
    -  Create thousands of “anchor boxes” or “prior boxes” for each predictor that represent the ideal location, 
       shape and size of the object it specializes in predicting.

'''

# %%
'''
YOLO is a clever convolutional neural network (CNN) for doing object detection in real-time.
Convolutional Neural Network architecture designed for the purpose of object detection.

There are 3 versions of YOLO:
    - version 1, version 2 and version 3.


'''

# %%
'''
How Yolo Works?

All of the previous object detection algorithms use regions to localize the object within the image. 
The network does not look at the complete image. 
Instead, parts of the image which have high probabilities of containing the object.


YOLO different from the region based algorithms seen above.
In YOLO a single convolutional network predicts the bounding boxes and the class probabilities for these boxes.

In Yolo, image split into an SxS grid, within each of the grid we take m bounding boxes. 
For each of the bounding box, the network outputs a class probability and offset values for the bounding box. 
The bounding boxes having the class probability above a threshold value is selected and used to locate the object 
within the image.

YOLO is orders of magnitude faster(45 frames per second) than other object detection algorithms

'''

'''
Limitation of YOLO :
    - The limitation of YOLO algorithm is that it struggles with small objects within the image.
'''

# %%
'''
YOLO Architecture:
    - This architecture takes an image as input and resizes it to 448*448 by keeping the aspect ratio same and 
      performing padding.
    - This image is then passed in the CNN network.
    - This model has 24 convolution layers, 4 max-pooling layers followed by 2 fully connected layers
    - For the reduction of the number of layers (Channels), we use 1*1 convolution that is followed by 3*3 convolution.
    - This model is trained on the ImageNet-1000 dataset. 

'''
