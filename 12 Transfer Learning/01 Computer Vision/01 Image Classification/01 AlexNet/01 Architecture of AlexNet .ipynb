# %%
'''

Input Size is 227*22 *2
It have 8 Layer (5 ConV and 2 Fully Connected and 1 Softmax Layer(Output))
RElu Activation Function used, 3 Conv layer have Maxpooling done after the Convolution

Inout + 5 Conv Layers + 2 FC Layer + 1 SoftMax Layer


'''

# %%
# Dimenson and Details

# %% [markdown]
# ![Tranfer%20Learning%20Architecture%20AlexNet.PNG](attachment:Tranfer%20Learning%20Architecture%20AlexNet.PNG)
