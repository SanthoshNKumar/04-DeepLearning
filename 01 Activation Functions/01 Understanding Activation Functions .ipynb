# %%
'''
    1. linear
    2. sigmoid
    3. Relu        : Rectified Linear Activation Function 
    4. Softmax
    5. Softplus
    6. Softsign
    7. Tanh        : Hyperbolic tangent activation function
    8. selu        : Scaled Exponential Linear Unit 
    9. elu         : Exponential Linear Unit
    10.gelu        : Gaussian error linear unit (GELU)
    11. swish
    12.hard_sigmoid 
    13.Exponential
    14.

'''

# %%
#1. Step Activation Function

#The step activation function only output two values based on input, 0 or 1.
# If the input value is below 0.5 the returned value is 0
# if the input value is 0.5 or above the returned value is 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#1. Sigmoid or Logistic Activation Function

# curve looks like a S-shape
# Range of the Function : 0 to 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#2. Tanh or Hyperbolic Tangent Function 

# Tanh is also like logistic sigmoid but better.
#  Range of the Function : -1 to 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ReLU or Rectified Linear Unit Function 

# f(z) is zero when z is less than zero and f(z) is equal to z when z is above or equal to zero.
# Range: [ 0 to infinity]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
LeakyReLU :

Leaky Rectified Linear Unit. This activation function also has an alpha α value, which is commonly between  0.1 to  0.3

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#3.Softmax Function

# The Softmax activation function compresses values to positive values between 0.0 and 1.0

# 1. Exponentiate every element of the output layer and sum the results (around 181.73 in this case)
# 2. Take each element of the output layer, 
# exponentiate it and divide by the sum obtained in 
# step 1 (exp(1.3) / 181.37 = 3.67 / 181.37 = 0.02)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
Softplus:
    Softplus : log(exp(x) + 1)

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
Softsign
    Softsign : x / (abs(x) + 1)

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
Exponential

'''

# %%
'''
ELUs : Exponential Linear Units
    This activation function fixes some of the problems with ReLUs and keeps some of the positive things. 
    For this activation function, an alpha  α value is picked; a common value is between 0.1 and 0.3

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
Selu : Scaled Exponential Linear Unit.

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''

Gelu : Gaussian Error Linear Unit. 

An activation function used in the most recent Transformers – Google's BERT 
and OpenAI's GPT-2. The paper is from 2016, but is only catching attention up until recently

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
Swish :

    f(x) = x*sigmoid(x)

'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
